# %%
#singularity pull docker://alpine/git
rm -rf /cluster/project/beltrao/jjaenes/euler-vibe/models
pull-model-eu mistralai/Mistral-Medium-3.5-128B
pull-model-eu Qwen/Qwen3.6-27B
pull-model-eu zai-org/GLM-5.1-FP8
