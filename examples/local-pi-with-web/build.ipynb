# %%
#docker build --progress plain -t pi-sandbox -f Dockerfile .
docker build --progress quiet -t pi-sandbox -f Dockerfile .
#docker run --rm -it pi-sandbox
# Out:
# sha256:e180abbf1ebce438ccb0ffeb7d026f2da2245823a01557f7244fd7b9348dfa58

# %%
#ssh -N -L 27183:eu-g6-026:27182 euler.ethz.ch
#export OPENAI_API_BASE=http://localhost:12346/v1
#export OPENAI_API_KEY=
#curl -s http://localhost:27183/v1/models | jq '.data[0]'

# %%
#mlx_lm.server --model mlx-community/gemma-4-12b-it-4bit --host 0.0.0.0 --port 10641
