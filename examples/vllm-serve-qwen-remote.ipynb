# %%
from pprint import pprint
from openai import OpenAI

client = OpenAI(api_key="EMPTY", base_url="http://eu-mi300-001:11434/v1")
resp = client.chat.completions.create(
    model="Qwen3.6-27B",
    messages=[{"role": "user", "content": "Write a haiku about protein-protein interactions in yeast."}],
    max_tokens=65536,
)
#dir(resp.choices[0].message)
print(resp.choices[0].message.content)
# Out:
# Yeast proteins embrace,
# Complexes form, signals spark,
# Budding life unfolds.

# %%
print(resp.choices[0].message.reasoning)
# Out:
# Thinking Process:
#
# 1.  **Deconstruct the request:**
#     *   Topic: Protein-protein interactions (PPIs) in yeast.
#     *   Form: Haiku (5-7-5 syllables).
#
# 2.  **Brainstorming keywords and concepts:**
#     *   Yeast: *Saccharomyces cerevisiae*, budding, single-celled, model organism, fermentation, baker's yeast.
#     *   PPIs: Binding, complex, network, handshake, dance, signal, pathway, yeast two-hybrid, interactome.
#     *   Imagery: Molecules meeting, locking together, signaling, life processes.
#
# 3.  **Drafting lines (Syllable counting):**
#     *   *Attempt 1:*
#         *   Yeast proteins meet up (5) -> Yeast pro-teins meet up (5). Good.
#         *   They bind together tight now (7) -> They bind to-geth-er tight now (7). Good.
#         *   Life goes on inside (5) -> Life goes on in-side (5). Good.
#         *   *Critique:* Too generic. "Life goes on inside" doesn't capture the specific science or poetry of PPIs well.
#
#     *   *Attempt 2:*
# ...
