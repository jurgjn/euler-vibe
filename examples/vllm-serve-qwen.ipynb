# %%
from pprint import pprint
from openai import OpenAI

client = OpenAI(api_key="EMPTY", base_url="http://localhost:8000/v1")
resp = client.chat.completions.create(
    model="Qwen3.6-27B",
    messages=[{"role": "user", "content": "Write a haiku about protein-protein interactions in yeast."}],
    max_tokens=65536,
)
#dir(resp.choices[0].message)
print(resp.choices[0].message.content)
# Out:
# Yeast proteins bind tight,
# Two-hybrid screens map the web,
# Life's network takes shape.

# %%
print(resp.choices[0].message.reasoning)
# Out:
# Thinking Process:
#
# 1.  **Deconstruct the request:**
#     *   Topic: Protein-protein interactions (PPIs) in yeast.
#     *   Form: Haiku (5-7-5 syllables).
#
# 2.  **Brainstorming keywords and concepts:**
#     *   Yeast: *Saccharomyces cerevisiae*, budding, single-celled, model organism, fermentation, genome project.
#     *   PPIs: Binding, complexes, networks, yeast two-hybrid, screens, partners, docking, function, signaling.
#     *   Imagery: Dancing, holding hands, networks, maps, yeast cells dividing.
#
# 3.  **Drafting lines (Syllable counting):**
#     *   *Attempt 1:*
#         *   Yeast proteins bind tight (5) -> Yeast pro-teins bind tight. (5) Good.
#         *   Two-hybrid screens find partners (7) -> Two-hy-brid screens find part-ners. (7) Good.
#         *   Networks map the cell (5) -> Net-works map the cell. (5) Good.
#         *   *Result:* Yeast proteins bind tight / Two-hybrid screens find partners / Networks map the cell.
#         *   *Critique:* Accurate, mentions "two-hybrid" which is iconic for yeast PPIs. A bit technical/dry, but fits the science.
#
#     *   *Attempt 2 (More poetic/biological focus):*
#         *   Budding yeast cells dance (5) -> Bud-ding yeast cells dance. (5) Good.
#         *   Proteins lock in complex pairs (7) -> Pro-teins lock in com-plex pairs. (7) Good.
#         *   Life flows through the net (5) -> Life flows through the net. (5) Good.
#         *   *Result:* Budding yeast cells dance / Proteins lock in complex pairs / Life flows through the net.
#         *   *Critique:* "Budding" is a nice yeast reference. "Complex pairs" is okay. "Life flows through the net" is a bit vague.
#
#     *   *Attempt 3 (Focusing on the "Yeast Two-Hybrid" method, as it's the gold standard for yeast PPIs):*
#         *   Bait and prey collide (5) -> Bait and prey col-lide. (5) Good.
#         *   Reporter genes light the way (7) -> Re-port-er genes light the way. (7) Good.
#         *   Maps of life emerge (5) -> Maps of life em-erge. (5) Good.
#         *   *Result:* Bait and prey collide / Reporter genes light the way / Maps of life emerge.
#         *   *Critique:* Very specific to the method. "Bait and prey" is standard terminology. Good for a scientist audience.
#
#     *   *Attempt 4 (Balancing general PPI and yeast context):*
#         *   Tiny yeast holds secrets (5) -> Ti-ny yeast holds se-crets. (5) Good.
#         *   Proteins shake hands in the dark (7) -> Pro-teins shake hands in the dark. (7) Good.
#         *   Networks weave the whole (5) -> Net-works weave the whole. (5) Good.
#         *   *Result:* Tiny yeast holds secrets / Proteins shake hands in the dark / Networks weave the whole.
#         *   *Critique:* "Shake hands" is a common metaphor for PPIs. "Tiny yeast" establishes the organism.
#
#     *   *Refining Attempt 1 (Strongest balance of accuracy and form):*
#         *   Yeast proteins bind tight (5)
#         *   Two-hybrid screens map the web (7) -> Two-hy-brid screens map the web. (7)
#         *   Life's network takes shape (5) -> Life's net-work takes shape. (5)
#         *   *Result:* Yeast proteins bind tight / Two-hybrid screens map the web / Life's network takes shape.
#         *   *Critique:* "Two-hybrid" is a strong keyword. "Map the web" refers to interaction networks. This feels solid.
#
#     *   *Final Polish (Mental check of syllables for the best candidate):*
#         *   Yeast proteins bind tight (Yeast pro-teins bind tight) -> 5 syllables.
#         *   Two-hybrid screens map the web (Two-hy-brid screens map the web) -> 7 syllables.
#         *   Life's network takes shape (Life's net-work takes shape) -> 5 syllables.
#         *   *Output:*
#         Yeast proteins bind tight,
#         Two-hybrid screens map the web,
#         Life's network takes shape.
#
#     *   *Alternative consideration:* Does the user want "Yeast" explicitly? Yes. Does it need to mention PPIs? Yes. The draft does both. "Two-hybrid" implies yeast PPIs strongly. "Proteins bind" implies PPI. "Yeast" is in line 1.
#
#     *   *Result looks good.*
