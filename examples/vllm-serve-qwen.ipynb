# %%
from pprint import pprint
from openai import OpenAI

client = OpenAI(api_key="EMPTY", base_url="http://localhost:11434/v1")
resp = client.chat.completions.create(
    model="Qwen3.6-27B",
    messages=[{"role": "user", "content": "Write a haiku about protein-protein interactions in yeast."}],
    max_tokens=65536,
)
#dir(resp.choices[0].message)
print(resp.choices[0].message.content)
# Out:
# Budding yeast awakes,
# Proteins dance and find mates,
# Complex webs of life.

# %%
print(resp.choices[0].message.reasoning)
# Out:
# Thinking Process:
#
# 1.  **Deconstruct the topic:** "Protein-protein interactions in yeast."
#     *   Keywords: Yeast, protein, interaction, binding, yeast two-hybrid (maybe too technical?), cellular machinery, budding, fermentation, life, bonds, partners.
#     *   Imagery: Tiny cells, proteins meeting, locking together, signaling, growth.
#
# 2.  **Brainstorming lines/phrases:**
#     *   Yeast cells divide fast.
#     *   Proteins find partners.
#     *   Bonds form in the cytoplasm.
#     *   Two-hybrid screens reveal secrets.
#     *   Life builds on these links.
#     *   Budding yeast, complex webs.
#     *   Amino acids touch.
#     *   Signals pass through.
#
# 3.  **Drafting Haikus (Syllable counting: 5-7-5):**
#     *   *Attempt 1:*
#         Yeast cells grow so fast (5)
#         Proteins meet and bind tight (7)
#         Life begins to bloom (5)
#         *Critique:* A bit generic. "Life begins to bloom" is okay, but doesn't capture the specific interaction aspect well.
#
#     *   *Attempt 2:*
#         Tiny yeast divides (5)
#         Partners lock in the cyto (7) -> "cyto" is a stretch for syllables, usually "cy-to-plasm" is 3, "cyto" might be 2. Let's check: Cy-to (2). "Partners lock in the cyto" is 7? Part-ners lock in the cy-to. 7 syllables. Okay.
#         Bonds of life are made (5)
#         *Critique:* "Cyto" feels awkward. "Bonds of life are made" is cliché.
#
#     *   *Attempt 3:*
#         Budding yeast awakes (5)
#         Proteins dance and find mates (7) -> Pro-teins dance and find mates. 7 syllables.
#         Complex webs of life (5) -> Com-plex webs of life. 5 syllables.
#         *Critique:* "Find mates" is a bit anthropomorphic but works for PPI. "Complex webs of life" is good imagery for interaction networks.
#         *Result:* Budding yeast awakes / Proteins dance and find mates / Complex webs of life.
#         *Syllables:* Bud-ding yeast a-wakes (5). Pro-teins dance and find mates (7). Com-plex webs of life (5).
#         *Verdict:* Strong candidate.
#
#     *   *Attempt 4 (More scientific flavor?):*
#         Yeast two-hybrid test (5)
#         Bait and prey come together (7)
#         Signals flow through cells (5)
#         *Critique:* "Yeast two-hybrid test" is very specific to the method, not the biological phenomenon itself. The prompt asks about PPIs, not the assay. Better to focus on the biology.
#
#     *   *Attempt 5 (Refining Attempt 3):*
#         Budding yeast awakes (5)
#         Partners lock in the dark (7) -> Part-ners lock in the dark. 7.
#         Life's network takes shape (5) -> Life's net-work takes shape. 5.
#         *Critique:* "In the dark" is poetic but maybe misleading? "Network" is a good word for PPI.
#         *Comparison:* Attempt 3 feels more natural. "Proteins dance" is a common metaphor.
#
#     *   *Attempt 6 (Focus on structure/binding):*
#         Amino chains meet (5)
#         Locking shapes in yeast cells (7) -> Lock-ing shapes in yeast cells. 7.
#         Bonds that build the whole (5) -> Bonds that build the whole. 5.
#         *Critique:* "Amino chains" is good. "Locking shapes" describes induced fit/complementarity. "Bonds that build the whole" implies function.
#         *Syllables:* A-mi-no chains meet (5). Lock-ing shapes in yeast cells (7). Bonds that build the whole (5).
#         *Verdict:* Also good, slightly more technical but still accessible.
#
#     *   *Selection:* Attempt 3 is very evocative. "Budding yeast awakes / Proteins dance and find mates / Complex webs of life."
#     *   *Check syllables again:*
#         Bud-ding yeast a-wakes. (5)
#         Pro-teins dance and find mates. (7)
#         Com-plex webs of life. (5)
#         *Perfect.*
#
#     *   *Alternative polish:* "Find mates" might be too sexual? "Find partners" is safer?
#         Pro-teins dance and find part-ners. (8 syllables). Too long.
#         Pro-teins seek their part-ners. (6 syllables). Too short.
#         Pro-teins bind with part-ners. (6 syllables).
#         Pro-teins link with part-ners. (6 syllables).
#         Pro-teins form tight bonds. (5 syllables).
#         So "Proteins dance and find mates" is actually the best fit rhythmically, and "mates" is widely used in biology for binding partners (e.g., mating types, though that's different, the metaphor holds). Or "Proteins meet and embrace"?
#         Pro-teins meet and em-brace. (6 syllables).
#         Pro-teins meet and em-brace tight. (7 syllables).
#         Budding yeast awakes / Proteins meet and embrace tight / Complex webs of life.
#         "Embrace tight" is a bit clunky.
#         I'll stick with "find mates" or "lock in place".
#         Pro-teins lock in place. (5 syllables).
#         Budding yeast awakes / Proteins lock in place within / Complex webs of life.
#         "Within" hangs awkwardly.
#         I think "Proteins dance and find mates" is the strongest poetic line that fits the meter. It conveys the dynamic nature of interactions.
#
#     *   *Final Output Construction:*
#         Budding yeast awakes,
#         Proteins dance and find mates,
#         Complex webs of life.
#
#         Or slightly more formal:
#         Budding yeast awakes,
#         Partners lock in the cell,
#         Networks shape the life.
#         Bud-ding yeast a-wakes (5).
#         Part-ners lock in the cell (6). Fail.
#         Part-ners lock in the cell now (7). Weak.
#         Part-ners bind in the cell (6).
#         Part-ners bind in the cell deep (7).
#         Budding yeast awakes / Partners bind in the cell deep / Networks shape the life.
#         "Cell deep" is weird.
#         Back to Attempt 3. It's the winner.
#
#         Budding yeast awakes,
#         Proteins dance and find mates,
#         Complex webs of life.
