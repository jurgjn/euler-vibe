# %%
export OPENAI_API_BASE=http://localhost:12345/v1
export OPENAI_API_KEY=

# %%
time curl -s $OPENAI_API_BASE/chat/completions \
    -H "Content-Type: application/json" \
    -d '{"messages": [{"role": "user", "content": "Write a haiku about the airspeed velocity of an unladen swallow"}]}' \
    | jq -r '.choices[0].message.content' \
    | fold -s -w 160
# Out:
# What kind of swallow?
# African or European?
# Carries coconut?
#
# real	0m14.894s
# user	0m0.009s
# sys	0m0.019s
