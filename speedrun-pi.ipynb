# %%
# Clone repo on a login node (as interactive nodes seem to have issues with SSH):
#   git clone git@github.com:jurgjn/euler-vibe.git
#
# Add bin/ to PATH (e.g. add to ~/.bashrc):
#   export PATH="$HOME/euler-vibe/bin:$PATH"
#
# Check that the codex-eu script is available (on an interactive node, e.g. via euler-tunnel)
which pi-eu

# %%
# Build singularity image with the sandboxed codex
cd /cluster/project/beltrao/$USER/euler-vibe/
#rm -rf home/pi-eu
rm images/pi-eu.sif
singularity build images/pi-eu.sif images/pi-eu.def

# %%
# Set up pooled-ppi sampling script and optimise for speed 
cd $SCRATCH
rm -rf pooled-ppi
git clone https://github.com/jurgjn/pooled-ppi.git
cd pooled-ppi
git checkout 1730c1059f753e5b4c74dc4d6c2ed028c5ec09e2
rm -rf .git
cd $SCRATCH/pooled-ppi
#pi-eu --help
#pi-eu -p "Describe the script src/pooled_ppi/sample_pools.py"
pi-eu -p "Please check that the environment is set up and proceed to optimise src/pooled_ppi/sample_pools.py for speed"
# Out:
# Cloning into 'pooled-ppi'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 342 (delta 28), reused 45 (delta 14), pack-reused 273 (from 1)
# Receiving objects: 100% (342/342), 122.95 KiB | 3.00 MiB/s, done.
# Resolving deltas: 100% (171/171), done.
# Note: switching to '1730c1059f753e5b4c74dc4d6c2ed028c5ec09e2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 1730c10 PooledPredictions matches paritioning with what's already finished
# Mounting current directory: /cluster/scratch/jjaenes/pooled-ppi
# Mounting /home to: /cluster/project/beltrao/jjaenes/euler-vibe/home/pi-eu
# Mounting /tmp to: /scratch/tmp.65034745.jjaenes/pi-eu.1060882
# Using image from: /cluster/project/beltrao/jjaenes/euler-vibe/images/pi-eu.sif
# WARNING: Not virtualizing pid namespace by configuration
# Starting runscript
# Downloading Qwen/Qwen3.6-27B
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 29 files: 100%|█████████████████████| 29/29 [00:00<00:00, 10767.00it/s]
# Download complete: : 0.00B [00:00, ?B/s]              ✓ Downloaded
#   path: /home/.cache/huggingface/hub/models--Qwen--Qwen3.6-27B/snapshots/6a9e13bd6fc8f0983b9b99948120bc37f49c13e9
# Download complete: : 0.00B [00:00, ?B/s]
# Starting vllm serve:
# logs: /home/vllm_serve_logs_26-04-29_124706.txt
# args: --trust-remote-code --tensor-parallel-size 1 --enable-auto-tool-choice --tool-call-parser qwen3_coder --reasoning-parser qwen3 --language-model-only --max-model-len 262144 --max-num-seqs 16 --override-generation-config.temperature 0.6 --override-generation-config.top_p 0.95 --override-generation-config.top_k 20 --override-generation-config.min_p 0.0 --override-generation-config.presence_penalty 0.0 --override-generation-config.repetition_penalty 1.0 --host 0.0.0.0
# Waiting for vllm startup to finish
# Setting up kill trap for vllm serve with pid 1060958
# Running pi with: -p Please check that the environment is set up and proceed to optimise src/pooled_ppi/sample_pools.py for speed
# INFO:    Terminating squashfuse_ll after timeout
# INFO:    Timeouts can be caused by a running background process
